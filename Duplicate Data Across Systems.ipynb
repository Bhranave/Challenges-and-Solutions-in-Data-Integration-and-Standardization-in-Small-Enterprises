# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('/content/drive/MyDrive/Thesis datasets/sales_data_sample - Copy.csv', encoding='latin1')

duplicates = data[data.duplicated()]
duplicates_specific = data[data.duplicated(subset=['Order No','Product Line','Quantity Ordered','Price Each','Orderline Number','Sales'])]
duplicate_names = duplicates_specific[['Order No','Product Line','Quantity Ordered','Price Each','Orderline Number','Sales']]

# Count total duplicates
duplicate_count = data.duplicated().sum()

# Print the total no of duplicates rows
print(f"Total number of duplicate rows: {duplicate_count}")
print(duplicate_names)
# Out:
# Total number of duplicate rows: 31
#      Order No      Product Line  Quantity Ordered  Price Each  \
# 1       10107       Motorcycles                30       95.70
# 9       10188       Motorcycles                48      100.00
# 19      10299       Motorcycles                23      100.00
# 29      10417       Motorcycles                66      100.00
# 39      10194      Classic Cars                42      100.00
# 49      10304      Classic Cars                47      100.00
# 59      10411      Classic Cars                23      100.00
# 69      10188       Motorcycles                38       96.34
# 79      10298       Motorcycles                39       96.34
# 89      10417       Motorcycles                45      100.00
# 99      10201       Motorcycles                49      100.00
# 109     10308       Motorcycles                20      100.00
# 119     10105      Classic Cars                50      100.00
# 129     10209      Classic Cars                39      100.00
# ...
