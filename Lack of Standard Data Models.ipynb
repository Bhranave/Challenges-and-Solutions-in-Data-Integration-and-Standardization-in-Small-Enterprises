# %%
import pandas as pd
from dateutil import parser

# Load the CSV file
data = pd.read_csv('/content/drive/MyDrive/Thesis datasets/sales_data_sample - Copy.csv', encoding='latin1')

# Combine 'First Name' and 'Last Name' into a new 'Full Name' column
data['Full Name'] = data['Contact First Name'] + ' ' + data['Contact Last Name']

# Display the updated Data
print(data)

# Save the updated Datamodel to a new CSV file
data.to_csv('output.csv', index=False)
print("\nUpdated CSV file saved as 'output.csv'")
# Out:
#       Order No  Quantity Ordered  Price Each  Orderline Number    Sales  \
# 0        10107                30       95.70                 2  2871.00
# 1        10107                30       95.70                 2  2871.00
# 2        10121                34       81.35                 5  2765.90
# 3        10134                41       94.74                 2  3884.34
# 4        10145                45       83.26                 6  3746.70
# ...        ...               ...         ...               ...      ...
# 2849     10350                20      100.00                15  2244.40
# 2850     10373                29      100.00                 1  3978.51
# 2851     10386                43      100.00                 4  5417.57
# 2852     10397                34       62.24                 1  2116.16
# 2853     10414                47       65.52                 9  3079.44
#
#      Order Date    Status  QTR_ID  Month_ID  Year_ID  ... Address Line2  \
# ...
